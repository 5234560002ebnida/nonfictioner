# %% [markdown]
# <a href="https://colab.research.google.com/github/5234560002ebnida/nonfictioner/blob/main/1~86pandas_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pandas 1~86번

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {"d" : [7,8,9,10],
     "e" : [18,19,21,22],
     "f" : [17, 19, 20, 21]},
     index=[5,6,7,8])

# %%
df
# Out:
#     d   e   f
# 5   7  18  17
# 6   8  19  19
# 7   9  21  20
# 8  10  22  21

# %%
df= pd.DataFrame(
    [[3,7,11],
    [5,8,13],
    [7,12,16],
    [17,18,20]],
    index=[5,6,7,8],
    columns=['d','e','f'])

# %%
df = pd.DataFrame(
    {"d" : [3,5,7,17],
     "e" : [7,8,12,18],
     "f" : [11,13,16,20]},
    index=pd.MultiIndex.from_tuples(
        [('g',1), ('g', 2),('h', 1),('h', 2) ],
        names=['l', 'm']))

# %%
df
# Out:
#       d   e   f
# l m
# g 1   3   7  11
#   2   5   8  13
# h 1   7  12  16
#   2  17  18  20

# %%
df.sort_values('e', ascending=False)
# Out:
#       d   e   f
# l m
# h 2  17  18  20
#   1   7  12  16
# g 2   5   8  13
#   1   3   7  11

# %%
df.rename(columns={'d':'p'})
# Out:
#       p   e   f
# l m
# g 1   3   7  11
#   2   5   8  13
# h 1   7  12  16
#   2  17  18  20

# %%
df.reset_index()
# Out:
#    l  m   d   e   f
# 0  g  1   3   7  11
# 1  g  2   5   8  13
# 2  h  1   7  12  16
# 3  h  2  17  18  20

# %%
df.drop(columns=['d', 'e'])
# Out:
#       f
# l m
# g 1  11
#   2  13
# h 1  16
#   2  20

# %%
df.head(1)
# Out:
#      d  e   f
# l m
# g 1  3  7  11

# %%
df.tail(1)
# Out:
#       d   e   f
# l m
# h 2  17  18  20

# %%
df[df["d"]>3]
# Out:
#       d   e   f
# l m
# g 2   5   8  13
# h 1   7  12  16
#   2  17  18  20

# %%
df[df["d"]>3]
# Out:
#       d   e   f
# l m
# g 2   5   8  13
# h 1   7  12  16
#   2  17  18  20

# %%
df[df["d"]==5]
# Out:
#      d  e   f
# l m
# g 2  5  8  13

# %%
df[df["d"] !=10]
# Out:
#       d   e   f
# l m
# g 1   3   7  11
#   2   5   8  13
# h 1   7  12  16
#   2  17  18  20

# %%
df[df['d'].isin([3])]
# Out:
#      d  e   f
# l m
# g 1  3  7  11

# %%
df.sample(frac=0.85)
# Out:
#      d   e   f
# l m
# g 2  5   8  13
# h 1  7  12  16
# g 1  3   7  11

# %%
df.sample(n=4)
# Out:
#       d   e   f
# l m
# g 2   5   8  13
#   1   3   7  11
# h 2  17  18  20
#   1   7  12  16

# %%
df.nlargest(4, 'd')
# Out:
#       d   e   f
# l m
# h 2  17  18  20
#   1   7  12  16
# g 2   5   8  13
#   1   3   7  11

# %%
df.nsmallest(4, 'd')
# Out:
#       d   e   f
# l m
# g 1   3   7  11
#   2   5   8  13
# h 1   7  12  16
#   2  17  18  20

# %%
df.iloc[2:4]
# Out:
#       d   e   f
# l m
# h 1   7  12  16
#   2  17  18  20

# %%
df.iloc[3:]
# Out:
#       d   e   f
# l m
# h 2  17  18  20

# %%
df.iloc[:1]
# Out:
#      d  e   f
# l m
# g 1  3  7  11

# %%
df.iloc[:]
# Out:
#       d   e   f
# l m
# g 1   3   7  11
#   2   5   8  13
# h 1   7  12  16
#   2  17  18  20

# %%
df[['d', 'e']]
# Out:
#       d   e
# l m
# g 1   3   7
#   2   5   8
# h 1   7  12
#   2  17  18

# %%
df.filter(regex='d')
# Out:
#       d
# l m
# g 1   3
#   2   5
# h 1   7
#   2  17

# %%
df.filter(regex='^(?!d$).*')
# Out:
#       e   f
# l m
# g 1   7  11
#   2   8  13
# h 1  12  16
#   2  18  20

# %%
df.loc[:, 'd':'e']
# Out:
#       d   e
# l m
# g 1   3   7
#   2   5   8
# h 1   7  12
#   2  17  18

# %%
df.iloc[1:4,[1,2]]
# Out:
#       e   f
# l m
# g 2   8  13
# h 1  12  16
#   2  18  20

# %%
df.loc[df['d']>7, ['d', 'e']]
# Out:
#       d   e
# l m
# h 2  17  18

# %%
df.iat[1,1]
# Out:
# 8

# %%
df = pd.DataFrame(
    {"d" : [7, 8, 9, 9, 10],
     "e" : [10, 11, 13, 13, 15],
     "f" : [20, 21, 23, 23,25]},
    index=pd.MultiIndex.from_tuples(
        [('g', 0),('g', 1), ('h', 2),('h', 2), ('k', 3)],
        names=['r', 's']))

# %%
df['d'].value_counts()
# Out:
# 9     2
# 7     1
# 8     1
# 10    1
# Name: d, dtype: int64

# %%
len(df)
# Out:
# 5

# %%
df.shape
# Out:
# (5, 3)

# %%
df['d'].nunique()
# Out:
# 4

# %%
df.describe()
# Out:
#                d          e          f
# count   5.000000   5.000000   5.000000
# mean    8.600000  12.400000  22.400000
# std     1.140175   1.949359   1.949359
# min     7.000000  10.000000  20.000000
# 25%     8.000000  11.000000  21.000000
# 50%     9.000000  13.000000  23.000000
# 75%     9.000000  13.000000  23.000000
# max    10.000000  15.000000  25.000000

# %%
df= df.drop_duplicates()

# %%
df
# Out:
#       d   e   f
# r s
# g 0   7  10  20
#   1   8  11  21
# h 2   9  13  23
# k 3  10  15  25

# %%
df.sum()
# Out:
# d    34
# e    49
# f    89
# dtype: int64

# %%
df.count()
# Out:
# d    4
# e    4
# f    4
# dtype: int64

# %%
df.median()
# Out:
# d     8.5
# e    12.0
# f    22.0
# dtype: float64

# %%
df['d'].mean()
# Out:
# 8.5

# %%
df.quantile([0.30, 0.70])
# Out:
#        d     e     f
# 0.3  7.9  10.9  20.9
# 0.7  9.1  13.2  23.2

# %%
df.min()
# Out:
# d     7
# e    10
# f    20
# dtype: int64

# %%
df.max()
# Out:
# d    10
# e    15
# f    25
# dtype: int64

# %%
df.std()
# Out:
# d    1.290994
# e    2.217356
# f    2.217356
# dtype: float64

# %%
import numpy as np
df.apply(np.sqrt)
# Out:
#             d         e         f
# r s
# g 0  2.645751  3.162278  4.472136
#   1  2.828427  3.316625  4.582576
# h 2  3.000000  3.605551  4.795832
# k 3  3.162278  3.872983  5.000000

# %%
df = pd.DataFrame(
    {"d" : [7,8,9, np.nan],
     "e" : [10,11, np.nan, 12],
     "f" : [13,np.nan,14, 15]},
    index=pd.MultiIndex.from_tuples(
        [('g', 1),('g', 2),('h', 0),('h', 2)],
        names=['l', 'm']))

# %%
df
# Out:
#        d     e     f
# l m
# g 1  7.0  10.0  13.0
#   2  8.0  11.0   NaN
# h 0  9.0   NaN  14.0
#   2  NaN  12.0  15.0

# %%
pd.isnull(df)
# Out:
#          d      e      f
# l m
# g 1  False  False  False
#   2  False  False   True
# h 0  False   True  False
#   2   True  False  False

# %%
pd.notnull(df)
# Out:
#          d      e      f
# l m
# g 1   True   True   True
#   2   True   True  False
# h 0   True  False   True
#   2  False   True   True

# %%
df_notnull = df.dropna()

df_notnull
# Out:
#        d     e     f
# l m
# g 1  7.0  10.0  13.0

# %%
df_fillna = df.fillna(14)

df_fillna
# Out:
#         d     e     f
# l m
# g 1   7.0  10.0  13.0
#   2   8.0  11.0  14.0
# h 0   9.0  14.0  14.0
#   2  14.0  12.0  15.0

# %%
df_fillna_mean = df.fillna(df['d'].mean())

df = pd.DataFrame(
    {"d" : [8,9,10,11],
     "e" : [12,13,14,15],
     "f" : [16,17,18,19]},
    index=pd.MultiIndex.from_tuples(
        [('g', 1),('g', 2),('h', 0),('h', 2)],
        names=['l', 'm']))

df
# Out:
#       d   e   f
# l m
# g 1   8  12  16
#   2   9  13  17
# h 0  10  14  18
#   2  11  15  19

# %%
df['sum'] = df['d']+df['e']+df['f']

df
# Out:
#       d   e   f  sum
# l m
# g 1   8  12  16   36
#   2   9  13  17   39
# h 0  10  14  18   42
#   2  11  15  19   45

# %%
df = df.assign(multiply=lambda df:df['d']*df['e']*df['f'])

df
# Out:
#       d   e   f  sum  multiply
# l m
# g 1   8  12  16   36      1536
#   2   9  13  17   39      1989
# h 0  10  14  18   42      2520
#   2  11  15  19   45      3135

# %%
df['qcut'] = pd.qcut(df['d'], 2, labels=["2000이하", "2000이상"])

df
# Out:
#       d   e   f  sum  multiply    qcut
# l m
# g 1   8  12  16   36      1536  2000이하
#   2   9  13  17   39      1989  2000이하
# h 0  10  14  18   42      2520  2000이상
#   2  11  15  19   45      3135  2000이상

# %%
df['clip'] = df['d'].clip(lower= 7, upper=8)
df
# Out:
#       d   e   f  sum  multiply    qcut  clip
# l m
# g 1   8  12  16   36      1536  2000이하     8
#   2   9  13  17   39      1989  2000이하     8
# h 0  10  14  18   42      2520  2000이상     8
#   2  11  15  19   45      3135  2000이상     8

# %%
df.max(axis=0)
# Out:
# d               11
# e               15
# f               19
# sum             45
# multiply      3135
# qcut        2000이상
# clip             8
# dtype: object

# %%
df.min(axis=0)
# Out:
# d                8
# e               12
# f               16
# sum             36
# multiply      1536
# qcut        2000이하
# clip             8
# dtype: object

# %%
df= pd.DataFrame({'D': {1: 'd', 2: 'e', 3:'f'},
                  'E': {1: 2, 2: 4, 3: 5},
                  'F': {1: 3, 2: 5, 3: 7}})

df
# Out:
#    D  E  F
# 1  d  2  3
# 2  e  4  5
# 3  f  5  7

# %%
pd.melt(df)
# Out:
#   variable value
# 0        D     d
# 1        D     e
# 2        D     f
# 3        E     2
# 4        E     4
# 5        E     5
# 6        F     3
# 7        F     5
# 8        F     7

# %%
pd.melt(df, id_vars=['D'], value_vars=['E'])
# Out:
#    D variable  value
# 0  d        E      2
# 1  e        E      4
# 2  f        E      5

# %%
df_melt = pd.melt(df, id_vars=['D'], value_vars=['E','F'])
df_melt
# Out:
#    D variable  value
# 0  d        E      2
# 1  e        E      4
# 2  f        E      5
# 3  d        F      3
# 4  e        F      5
# 5  f        F      7

# %%
df_pivot = df_melt.pivot(index='D', columns='variable', values='value')
df_pivot
# Out:
# variable  E  F
# D
# d         2  3
# e         4  5
# f         5  7

# %%
df_origin = df_pivot.reset_index()
df_origin.columns.name = None
df_origin
# Out:
#    D  E  F
# 0  d  2  3
# 1  e  4  5
# 2  f  5  7

# %%
s1 = pd.Series(['d', 'e'])
s1
# Out:
# 0    d
# 1    e
# dtype: object

# %%
s2= pd.Series(['e', 'f'])
s2
# Out:
# 0    e
# 1    f
# dtype: object

# %%
pd.concat([s1, s2])
# Out:
# 0    d
# 1    e
# 0    e
# 1    f
# dtype: object

# %%
pd.concat([s1,s2], ignore_index=True)
# Out:
# 0    d
# 1    e
# 2    e
# 3    f
# dtype: object

# %%
pd.concat([s1,s2],
          keys=['s1', 's2'],
          names=['Series name', 'Row ID'])
# Out:
# Series name  Row ID
# s1           0         d
#              1         e
# s2           0         e
#              1         f
# dtype: object

# %%
df1 = pd.DataFrame([['d', 2],
                   ['e', 3]],
                   columns=['letter', 'number'])
df1
# Out:
#   letter  number
# 0      d       2
# 1      e       3

# %%
df2 = pd.DataFrame([['f', 5],
                   ['g', 6]],
                   columns=['letter', 'number'])
df2
# Out:
#   letter  number
# 0      f       5
# 1      g       6

# %%
df3 = pd.DataFrame([['l', 7, 'lime'],
                   ['w', 8, 'watermelon']],
                   columns=['letter', 'number', 'fruit'])
df3
# Out:
#   letter  number       fruit
# 0      l       7        lime
# 1      w       8  watermelon

# %%
df4 = pd.DataFrame([['dog', 'mike'],
                   ['bird', 'molly']],
                   columns=['animal', 'name'])
df4
# Out:
#   animal   name
# 0    dog   mike
# 1   bird  molly

# %%
pd.concat([df1, df2])
# Out:
#   letter  number
# 0      d       2
# 1      e       3
# 0      f       5
# 1      g       6

# %%
pd.concat([df1, df3])
# Out:
#   letter  number       fruit
# 0      d       2         NaN
# 1      e       3         NaN
# 0      l       7        lime
# 1      w       8  watermelon

# %%
pd.concat([df1, df3], join="inner")
# Out:
#   letter  number
# 0      d       2
# 1      e       3
# 0      l       7
# 1      w       8

# %%
pd.concat([df1, df4], axis=1)
# Out:
#   letter  number animal   name
# 0      d       2    dog   mike
# 1      e       3   bird  molly

# %%
adf = pd.DataFrame({"x1" : ["D","E","F"],
                    "x2" : [4,5,6]})
adf
# Out:
#   x1  x2
# 0  D   4
# 1  E   5
# 2  F   6

# %%
bdf = pd.DataFrame({"x1" : ["D","E","N"],
                    "x3" : ["T","F","T"]})
bdf
# Out:
#   x1 x3
# 0  D  T
# 1  E  F
# 2  N  T

# %%
cdf = pd.DataFrame({"x1" : ["E","F","N"],
                    "x2" : ["5","6", "7"]})
cdf
# Out:
#   x1 x2
# 0  E  5
# 1  F  6
# 2  N  7

# %%
pd.merge(adf, bdf, how='left', on='x1')
# Out:
#   x1  x2   x3
# 0  D   4    T
# 1  E   5    F
# 2  F   6  NaN

# %%
pd.merge(adf, bdf, how='right', on='x1')
# Out:
#   x1   x2 x3
# 0  D  4.0  T
# 1  E  5.0  F
# 2  N  NaN  T

# %%
pd.merge(adf, bdf, how='inner', on='x1')
# Out:
#   x1  x2 x3
# 0  D   4  T
# 1  E   5  F

# %%
pd.merge(adf, bdf, how='outer', on='x1')
# Out:
#   x1   x2   x3
# 0  D  4.0    T
# 1  E  5.0    F
# 2  F  6.0  NaN
# 3  N  NaN    T

# %%
adf[adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 0  D   4
# 1  E   5

# %%
adf[~adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 2  F   6

# %%
pd.merge(bdf,cdf)
# Out:
#   x1 x3 x2
# 0  E  F  5
# 1  N  T  7

# %%
pd.merge(bdf,cdf, how='outer')
# Out:
#   x1   x3   x2
# 0  D    T  NaN
# 1  E    F    5
# 2  N    T    7
# 3  F  NaN    6

# %%
pd.merge(bdf, cdf, how='outer', indicator=True)
# Out:
#   x1   x3   x2      _merge
# 0  D    T  NaN   left_only
# 1  E    F    5        both
# 2  N    T    7        both
# 3  F  NaN    6  right_only

# %%
pd.merge(bdf, cdf, how='outer', indicator=True).query('_merge=="left_only"')
# Out:
#   x1 x3   x2     _merge
# 0  D  T  NaN  left_only

# %%
df = pd.DataFrame(
    {"d" : [8,9,10,11],
     "e" : [12,13,14,15],
     "f" : [16,17,18,19]},
    index= [2,3,4,5])
df
# Out:
#     d   e   f
# 2   8  12  16
# 3   9  13  17
# 4  10  14  18
# 5  11  15  19

# %%
df.shift(2)
# Out:
#      d     e     f
# 2  NaN   NaN   NaN
# 3  NaN   NaN   NaN
# 4  8.0  12.0  16.0
# 5  9.0  13.0  17.0

# %%
df.shift(-2)
# Out:
#       d     e     f
# 2  10.0  14.0  18.0
# 3  11.0  15.0  19.0
# 4   NaN   NaN   NaN
# 5   NaN   NaN   NaN

# %%
df.cumsum()
# Out:
#     d   e   f
# 2   8  12  16
# 3  17  25  33
# 4  27  39  51
# 5  38  54  70

# %%
df.cummax()
# Out:
#     d   e   f
# 2   8  12  16
# 3   9  13  17
# 4  10  14  18
# 5  11  15  19

# %%
df.cummin()
# Out:
#    d   e   f
# 2  8  12  16
# 3  8  12  16
# 4  8  12  16
# 5  8  12  16

# %%
df.cumprod()
# Out:
#       d      e      f
# 2     8     12     16
# 3    72    156    272
# 4   720   2184   4896
# 5  7920  32760  93024
